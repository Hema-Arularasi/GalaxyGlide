# %%
score = 0

print("Welcome to the Space Quiz!")
print("Answer the following 10 questions to test your space knowledge.")

# Question 1
print("\n1. What is the largest planet in our solar system?")
print("a) Saturn")
print("b) Jupiter")
print("c) Mars")
answer1 = input("Enter your choice (a, b, or c): ")
if answer1.lower() == "b":
    print("Correct!")
    score += 1
else:
    print("Incorrect. The correct answer is b) Jupiter.")

# Question 2
print("\n2. Which planet is known as the 'Red Planet'?")
print("a) Venus")
print("b) Mars")
print("c) Neptune")
answer2 = input("Enter your choice (a, b, or c): ")
if answer2.lower() == "b":
    print("Correct!")
    score += 1
else:
    print("Incorrect. The correct answer is b) Mars.")

# Question 3
print("\n3. What is the name of the first artificial satellite launched into space?")
print("a) Hubble")
print("b) Voyager 1")
print("c) Sputnik")
answer3 = input("Enter your choice (a, b, or c): ")
if answer3.lower() == "c":
    print("Correct!")
    score += 1
else:
    print("Incorrect. The correct answer is c) Sputnik.")

# Question 4
print("\n4. Which galaxy is our solar system part of?")
print("a) Andromeda")
print("b) Milky Way")
print("c) Triangulum")
answer4 = input("Enter your choice (a, b, or c): ")
if answer4.lower() == "b":
    print("Correct!")
    score += 1
else:
    print("Incorrect. The correct answer is b) Milky Way.")

# Question 5
print("\n5. What is the name of the brightest star in our night sky?")
print("a) Betelgeuse")
print("b) Sirius")
print("c) Vega")
answer5 = input("Enter your choice (a, b, or c): ")
if answer5.lower() == "b":
    print("Correct!")
    score += 1
else:
    print("Incorrect. The correct answer is b) Sirius.")

# Question 6
print("\n6. How many moons does Earth have?")
print("a) 1")
print("b) 2")
print("c) 3")
answer6 = input("Enter your choice (a, b, or c): ")
if answer6.lower() == "a":
    print("Correct!")
    score += 1
else:
    print("Incorrect. The correct answer is a) 1.")

# Question 7
print("\n7. Who was the first human to journey into space?")
print("a) Neil Armstrong")
print("b) Yuri Gagarin")
print("c) Buzz Aldrin")
answer7 = input("Enter your choice (a, b, or c): ")
if answer7.lower() == "b":
    print("Correct!")
    score += 1
else:
    print("Incorrect. The correct answer is b) Yuri Gagarin.")

# Question 8
print("\n8. What is the name of the largest moon of Saturn?")
print("a) Europa")
print("b) Titan")
print("c) Ganymede")
answer8 = input("Enter your choice (a, b, or c): ")
if answer8.lower() == "b":
    print("Correct!")
    score += 1
else:
    print("Incorrect. The correct answer is b) Titan.")

# Question 9
print("\n9. What is the speed of light in a vacuum? (Give your answer in km/s)")
print("a) 299,792.458")
print("b) 150,000")
print("c) 500,000")
answer9 = input("Enter your choice (a, b, or c): ")
if answer9.lower() == "a":
    print("Correct!")
    score += 1
else:
    print("Incorrect. The correct answer is a) 299,792.458 km/s.")

# Question 10
print("\n10. What is the name of the phenomenon where light is bent as it passes through a gravitational field?")
print("a) Black Hole")
print("b) Dark Matter")
print("c) Gravitational Lensing")
answer10 = input("Enter your choice (a, b, or c): ")
if answer10.lower() == "c":
    print("Correct!")
    score += 1
else:
    print("Incorrect. The correct answer is c) Gravitational Lensing.")

# Display final score
print("\nQuiz completed! Your final score is:", score)
# Out:
# Welcome to the Space Quiz!
# Answer the following 10 questions to test your space knowledge.
#
# 1. What is the largest planet in our solar system?
# a) Saturn
# b) Jupiter
# c) Mars
# Enter your choice (a, b, or c): b
# Correct!
#
# 2. Which planet is known as the 'Red Planet'?
# a) Venus
# b) Mars
# c) Neptune
# Enter your choice (a, b, or c): b
# Correct!
#
# 3. What is the name of the first artificial satellite launched into space?
# a) Hubble
# b) Voyager 1
# c) Sputnik
# Enter your choice (a, b, or c): c
# Correct!
#
# 4. Which galaxy is our solar system part of?
# a) Andromeda
# b) Milky Way
# c) Triangulum
# Enter your choice (a, b, or c): b
# Correct!
#
# 5. What is the name of the brightest star in our night sky?
# a) Betelgeuse
# b) Sirius
# c) Vega
# Enter your choice (a, b, or c): b
# Correct!
#
# 6. How many moons does Earth have?
# a) 1
# b) 2
# c) 3
# Enter your choice (a, b, or c): a
# Correct!
#
# 7. Who was the first human to journey into space?
# ...
